# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


pd.set_option("display.max_rows", None)
pd.reset_option("display.max_rows")

# %%
# a = pd.read_parquet(r"../data/series_train_parquet/id=00115b9f/part-0.parquet")

# %%
# a
# Out:
#         step         X         Y         Z      enmo     anglez  \
# 0          0  0.021536  0.022214 -1.022370  0.022853 -88.280762
# 1          1  0.022005  0.022187 -1.019740  0.020231 -88.241707
# 2          2  0.022240  0.022005 -1.019401  0.019893 -88.170067
# 3          3  0.021589  0.022578 -1.018177  0.018667 -88.250031
# 4          4  0.022005  0.023763 -1.014323  0.016848 -88.130775
# ...      ...       ...       ...       ...       ...        ...
# 43325  43325 -0.008333 -0.023620 -1.006901  0.007224 -88.595741
# 43326  43326  0.048730 -0.076725 -0.953776  0.056839 -85.352219
# 43327  43327  0.387370  0.793151 -0.402214  0.069961 -24.097908
# 43328  43328  0.801953  0.501589 -0.040937  0.045489  -2.113776
# 43329  43329  0.792144  0.170486 -0.413108  0.063103 -16.771301
#
#        non-wear_flag      light  battery_voltage     time_of_day  weekday  \
# 0                0.0  53.000000      4188.000000  56940000000000        4
# ...

# %% [markdown]
# ## Getting the Pad Data

# %%
pad = pd.read_csv(r"../data/train.csv")

# %%
pad
# Out:
#             id Basic_Demos-Enroll_Season  Basic_Demos-Age  Basic_Demos-Sex  \
# 0     00008ff9                      Fall                5                0
# 1     000fd460                    Summer                9                0
# 2     00105258                    Summer               10                1
# 3     00115b9f                    Winter                9                0
# 4     0016bb22                    Spring               18                1
# ...        ...                       ...              ...              ...
# 3955  ff8a2de4                      Fall               13                0
# 3956  ffa9794a                    Winter               10                0
# 3957  ffcd4dbd                      Fall               11                0
# 3958  ffed1dd5                    Spring               13                0
# 3959  ffef538e                    Spring               11                0
#
#      CGAS-Season  CGAS-CGAS_Score Physical-Season  Physical-BMI  \
# ...

# %% [markdown]
# ## Checking For Nulls

# %%
pd.set_option("display.max_rows", None)

# %%
nulls = pd.DataFrame({
    "Feature" : pad.isnull().sum().index,
    "Nulls" : pad.isnull().sum().values,
    "Percent" : list(map(lambda x : f"{x*100:.3f}%", pad.isnull().sum().values/pad.shape[0]))
})

nulls.sort_values("Nulls", ascending=False)
# Out:
#                                    Feature  Nulls  Percent
# 51                       PAQ_A-PAQ_A_Total   3485  88.005%
# 50                            PAQ_A-Season   3485  88.005%
# 17              Fitness_Endurance-Time_Sec   3220  81.313%
# 16             Fitness_Endurance-Time_Mins   3220  81.313%
# 15             Fitness_Endurance-Max_Stage   3217  81.237%
# 10            Physical-Waist_Circumference   3062  77.323%
# 22                       FGC-FGC_GSND_Zone   2898  73.182%
# 24                        FGC-FGC_GSD_Zone   2897  73.157%
# 23                             FGC-FGC_GSD   2886  72.879%
# 21                            FGC-FGC_GSND   2886  72.879%
# 14                Fitness_Endurance-Season   2652  66.970%
# 52                            PAQ_C-Season   2239  56.540%
# 53                       PAQ_C-PAQ_C_Total   2239  56.540%
# 38                             BIA-BIA_DEE   1969  49.722%
# 40                             BIA-BIA_FFM   1969  49.722%
# ...

# %%
pd.reset_option("display.max_rows")
